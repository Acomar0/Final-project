# %%
from image_classifier import *
# Import x and y variables using 
# file_name.variable_name notation
# Import x and y variables using 
# file_name.variable_name notation

# %%
img_height=128

# %%
classifier()
# Out:
# Please input folder:
# AI
# Please input file name:
# ml
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13216\2250737855.py in <module>
# ----> 1 classifier()
#
# ~\Ironhack\Week_9\Final_project\Notebooks\image_classifier.py in classifier()
#     109
#     110     img = tf.keras.utils.load_img(
# --> 111     image_path, target_size=(img_height, img_width)
#     112 )
#     113     img_array = tf.keras.utils.img_to_array(img)
#
# NameError: name 'img_height' is not defined
